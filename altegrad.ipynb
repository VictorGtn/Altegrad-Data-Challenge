# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # dataimport os
import os.path as osp
import torch
# !pip install torch_geometric
from torch_geometric.data import Dataset 
from torch_geometric.data import Data
from torch.utils.data import Dataset as TorchDataset
import pandas as pd

class GraphTextDataset(Dataset):
    def __init__(self, root, gt, split, tokenizer=None, transform=None, pre_transform=None):
        self.root = root
        self.gt = gt
        self.split = split
        self.tokenizer = tokenizer
        self.description = pd.read_csv(os.path.join(self.root, split+'.tsv'), sep='\t', header=None)   
        self.description = self.description.set_index(0).to_dict()
        self.cids = list(self.description[1].keys())
        
        self.idx_to_cid = {}
        i = 0
        for cid in self.cids:
            self.idx_to_cid[i] = cid
            i += 1
        super(GraphTextDataset, self).__init__(root, transform, pre_transform)

    @property
    def raw_file_names(self):
        return [str(cid) + ".graph" for cid in self.cids]

    @property
    def processed_file_names(self):
        return ['data_{}.pt'.format(cid) for cid in self.cids]
    
    @property
    def raw_dir(self) -> str:
        return osp.join(self.root, 'raw')

    @property
    def processed_dir(self) -> str:
        return osp.join(self.root, 'processed/', self.split)

    def download(self):
        pass
        
    def process_graph(self, raw_path):
      edge_index  = []
      x = []
      with open(raw_path, 'r') as f:
        next(f)
        for line in f: 
          if line != "\n":
            edge = *map(int, line.split()), 
            edge_index.append(edge)
          else:
            break
        next(f)
        for line in f: #get mol2vec features:
          substruct_id = line.strip().split()[-1]
          if substruct_id in self.gt.keys():
            x.append(self.gt[substruct_id])
          else:
            x.append(self.gt['UNK'])
        return torch.LongTensor(edge_index).T, torch.FloatTensor(x)

    def process(self):
        i = 0        
        for raw_path in self.raw_paths:
            cid = int(raw_path.split('/')[-1][:-6])
            text_input = self.tokenizer([self.description[1][cid]],
                                   return_tensors="pt", 
                                   truncation=True, 
                                   max_length=256,
                                   padding="max_length",
                                   add_special_tokens=True,)
            edge_index, x = self.process_graph(raw_path)
            data = Data(x=x, edge_index=edge_index, input_ids=text_input['input_ids'], attention_mask=text_input['attention_mask'])

            torch.save(data, osp.join(self.processed_dir, 'data_{}.pt'.format(cid)))
            i += 1

    def len(self):
        return len(self.processed_file_names)

    def get(self, idx):
        data = torch.load(osp.join(self.processed_dir, 'data_{}.pt'.format(self.idx_to_cid[idx])))
        return data

    def get_cid(self, cid):
        data = torch.load(osp.join(self.processed_dir, 'data_{}.pt'.format(cid)))
        return data
    
    
class GraphDataset(Dataset):
    def __init__(self, root, gt, split, transform=None, pre_transform=None):
        self.root = root
        self.gt = gt
        self.split = split
        self.description = pd.read_csv(os.path.join(self.root, split+'.txt'), sep='\t', header=None)
        self.cids = self.description[0].tolist()
        
        self.idx_to_cid = {}
        i = 0
        for cid in self.cids:
            self.idx_to_cid[i] = cid
            i += 1
        super(GraphDataset, self).__init__(root, transform, pre_transform)

    @property
    def raw_file_names(self):
        return [str(cid) + ".graph" for cid in self.cids]

    @property
    def processed_file_names(self):
        return ['data_{}.pt'.format(cid) for cid in self.cids]
    
    @property
    def raw_dir(self) -> str:
        return osp.join(self.root, 'raw')

    @property
    def processed_dir(self) -> str:
        return osp.join(self.root, 'processed/', self.split)

    def download(self):
        pass
        
    def process_graph(self, raw_path):
      edge_index  = []
      x = []
      with open(raw_path, 'r') as f:
        next(f)
        for line in f: 
          if line != "\n":
            edge = *map(int, line.split()), 
            edge_index.append(edge)
          else:
            break
        next(f)
        for line in f:
          substruct_id = line.strip().split()[-1]
          if substruct_id in self.gt.keys():
            x.append(self.gt[substruct_id])
          else:
            x.append(self.gt['UNK'])
        return torch.LongTensor(edge_index).T, torch.FloatTensor(x)

    def process(self):
        i = 0        
        for raw_path in self.raw_paths:
            cid = int(raw_path.split('/')[-1][:-6])
            edge_index, x = self.process_graph(raw_path)
            data = Data(x=x, edge_index=edge_index)
            torch.save(data, osp.join(self.processed_dir, 'data_{}.pt'.format(cid)))
            i += 1

    def len(self):
        return len(self.processed_file_names)

    def get(self, idx):
        data = torch.load(osp.join(self.processed_dir, 'data_{}.pt'.format(self.idx_to_cid[idx])))
        return data

    def get_cid(self, cid):
        data = torch.load(osp.join(self.processed_dir, 'data_{}.pt'.format(cid)))
        return data
    
    def get_idx_to_cid(self):
        return self.idx_to_cid
    
class TextDataset(TorchDataset):
    def __init__(self, file_path, tokenizer, max_length=256):
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.sentences = self.load_sentences(file_path)

    def load_sentences(self, file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        return [line.strip() for line in lines]

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        sentence = self.sentences[idx]

        encoding = self.tokenizer.encode_plus(
            sentence,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze()
        }
# Out:
# Collecting torch_geometric
#   Obtaining dependency information for torch_geometric from https://files.pythonhosted.org/packages/65/4e/6f9a75548a93fedcd4514ae2de9bee1e91bade6b73252b4da32f0e42ac52/torch_geometric-2.4.0-py3-none-any.whl.metadata
#   Downloading torch_geometric-2.4.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)
# Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.4.0
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from torch import nn
import torch.nn.functional as F
from torch.nn import Sequential
from torch.nn import GRUCell, Linear
from torch_geometric.nn import GCNConv
from torch_geometric.nn import SAGPooling, TopKPooling,global_add_pool,TransformerConv,PointTransformerConv
from transformers import AutoModel


import torch.nn as nn
from torch_geometric.nn import GINConv, SAGPooling

import torch.nn as nn
from torch_geometric.nn import GATConv, TopKPooling, global_max_pool


class GraphEncoder(nn.Module):
    def __init__(self, num_node_features, nout, nhid, graph_hidden_channels):
        super(GraphEncoder, self).__init__()
        self.nhid = nhid
        self.nout = nout
        self.leaky_relu = nn.LeakyReLU(0.2)
        self.ln = nn.LayerNorm((nout))
        
        
        # Replace GINConv with GATConv
        self.conv1 = GATConv(num_node_features,graph_hidden_channels,heads=20)
        self.conv2 = GATConv(20*graph_hidden_channels,graph_hidden_channels,heads=20)
        self.conv3 = GATConv(20*graph_hidden_channels,graph_hidden_channels,heads=20)




        
        # Add TopKPooling layer


        self.mol_hidden1 = nn.Linear(20*graph_hidden_channels, nhid)
        self.mol_hidden2 = nn.Linear(nhid, nout)

    def forward(self, graph_batch):
            x = graph_batch.x
            #'x', 'edge_index', 'edge_weight', 'edge_attr', 'y', 'pos', 'batch',

            edge_index = graph_batch.edge_index
            batch = graph_batch.batch
            edge_attr = graph_batch.edge_attr
            y = graph_batch.y
            pos = graph_batch.pos
            edge_weight = graph_batch.edge_weight
            
                    
            x = self.conv1(x, edge_index)
            x = x.relu()

            x = self.conv2(x, edge_index)
            x = x.relu()

            x = self.conv3(x, edge_index)
            
            
            x = global_max_pool(x, batch)

            # Apply dense layers
            x = self.mol_hidden1(x).relu()
            x = self.mol_hidden2(x)
        

            return x


    
class TextEncoder(nn.Module):
    def __init__(self, model_name):
        super(TextEncoder, self).__init__()
        self.bert = AutoModel.from_pretrained(model_name)
        
    def forward(self, input_ids, attention_mask):
        encoded_text = self.bert(input_ids, attention_mask=attention_mask)
        #print(encoded_text.last_hidden_state.size())
        return encoded_text.last_hidden_state[:,0,:]
    
class Model(nn.Module):
    def __init__(self, model_name, num_node_features, nout, nhid, graph_hidden_channels):
        super(Model, self).__init__()
        self.graph_encoder = GraphEncoder(num_node_features, nout, nhid, graph_hidden_channels)
        self.text_encoder = TextEncoder(model_name)
        
    def forward(self, graph_batch, input_ids, attention_mask):
        graph_encoded = self.graph_encoder(graph_batch)
        text_encoded = self.text_encoder(input_ids, attention_mask)
        return graph_encoded, text_encoded
    
    def get_text_encoder(self):
        return self.text_encoder
    
    def get_graph_encoder(self):
        return self.graph_encoder

# %%
from torch_geometric.data import DataLoader
from torch.utils.data import DataLoader as TorchDataLoader
import numpy as np
from transformers import AutoTokenizer
import torch
from torch import optim
import time
import os
import pandas as pd
from torch.optim.lr_scheduler import StepLR
import timm
from timm.scheduler import CosineLRScheduler


CE = torch.nn.CrossEntropyLoss()
def contrastive_loss(v1, v2):
  logits = torch.matmul(v1,torch.transpose(v2, 0, 1))
  labels = torch.arange(logits.shape[0], device=v1.device)
  return CE(logits, labels) + CE(torch.transpose(logits, 0, 1), labels)

model_name = "dmis-lab/biobert-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
gt = np.load("/kaggle/input/biobert/data/token_embedding_dict.npy", allow_pickle=True)[()]
val_dataset = GraphTextDataset(root='/kaggle/input/biobert/data/', gt=gt, split='val', tokenizer=tokenizer)
train_dataset = GraphTextDataset(root='/kaggle/input/biobert/data/', gt=gt, split='train', tokenizer=tokenizer)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

nb_epochs = 35
batch_size = 16
learning_rate = 0.00002

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

model = Model(model_name=model_name, num_node_features=300, nout=768, nhid=500, graph_hidden_channels=500) # nout = bert model hidden dim

model.to(device)

optimizer = optim.AdamW(model.parameters(), lr=learning_rate,
                                betas=(0.9, 0.999),
                                weight_decay=0.01)

scheduler = CosineLRScheduler(optimizer, t_initial=10)

epoch = 0
loss = 0
losses = []
count_iter = 0
time1 = time.time()
printEvery = 50
best_validation_loss = 100000

for i in range(nb_epochs):
    print('-----EPOCH{}-----'.format(i+1))
    model.train()
    for batch in train_loader:
        input_ids = batch.input_ids
        batch.pop('input_ids')
        attention_mask = batch.attention_mask
        batch.pop('attention_mask')
        graph_batch = batch
        
        x_graph, x_text = model(graph_batch.to(device), 
                                input_ids.to(device), 
                                attention_mask.to(device))
        current_loss = contrastive_loss(x_graph, x_text)   
        optimizer.zero_grad()
        current_loss.backward()
        optimizer.step()
        loss += current_loss.item()
        
        count_iter += 1
        if count_iter % printEvery == 0:
            time2 = time.time()
            print("Iteration: {0}, Time: {1:.4f} s, training loss: {2:.4f}".format(count_iter,
                                                                        time2 - time1, loss/printEvery))
            losses.append(loss)
            loss = 0 
    model.eval()       
    val_loss = 0        
    for batch in val_loader:
        input_ids = batch.input_ids
        batch.pop('input_ids')
        attention_mask = batch.attention_mask
        batch.pop('attention_mask')
        graph_batch = batch
        x_graph, x_text = model(graph_batch.to(device), 
                                input_ids.to(device), 
                                attention_mask.to(device))
        current_loss = contrastive_loss(x_graph, x_text)   
        val_loss += current_loss.item()
    best_validation_loss = min(best_validation_loss, val_loss)
    print('-----EPOCH'+str(i+1)+'----- done.  Validation loss: ', str(val_loss/len(val_loader)) )
    if best_validation_loss==val_loss:
        print('validation loss improoved saving checkpoint...')
        save_path = os.path.join('./', 'model'+'.pt')
        torch.save({
        'epoch': i,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'validation_accuracy': val_loss,
        'loss': loss,
        }, save_path)
        print('checkpoint saved to: {}'.format(save_path))
        
    scheduler.step(i+1)


print('loading best model...')
checkpoint = torch.load(save_path)
model.load_state_dict(checkpoint['model_state_dict'])

model.eval()

graph_model = model.get_graph_encoder()
text_model = model.get_text_encoder()

test_cids_dataset = GraphDataset(root='/kaggle/input/biobert/data', gt=gt, split='test_cids')
test_text_dataset = TextDataset(file_path='/kaggle/input/biobert/data/test_text.txt', tokenizer=tokenizer)

idx_to_cid = test_cids_dataset.get_idx_to_cid()

test_loader = DataLoader(test_cids_dataset, batch_size=batch_size, shuffle=False)

graph_embeddings = []
for batch in test_loader:
    for output in graph_model(batch.to(device)):
        graph_embeddings.append(output.tolist())

test_text_loader = TorchDataLoader(test_text_dataset, batch_size=batch_size, shuffle=False)
text_embeddings = []
for batch in test_text_loader:
    for output in text_model(batch['input_ids'].to(device), 
                             attention_mask=batch['attention_mask'].to(device)):
        text_embeddings.append(output.tolist())


from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(text_embeddings, graph_embeddings)

solution = pd.DataFrame(similarity)
solution['ID'] = solution.index
solution = solution[['ID'] + [col for col in solution.columns if col!='ID']]
solution.to_csv('submission.csv', index=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# -----EPOCH1-----
# /opt/conda/lib/python3.10/site-packages/torch_geometric/warnings.py:17: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# Iteration: 50, Time: 36.3281 s, training loss: 3.8838
# Iteration: 100, Time: 72.4673 s, training loss: 2.1106
# Iteration: 150, Time: 108.3498 s, training loss: 1.5001
# Iteration: 200, Time: 144.3015 s, training loss: 1.3111
# Iteration: 250, Time: 180.0040 s, training loss: 1.1803
# Iteration: 300, Time: 217.0444 s, training loss: 0.9835
# Iteration: 350, Time: 253.1966 s, training loss: 0.8584
# Iteration: 400, Time: 288.9819 s, training loss: 0.7498
# Iteration: 450, Time: 324.9278 s, training loss: 0.7441
# Iteration: 500, Time: 360.7778 s, training loss: 0.5283
# Iteration: 550, Time: 396.4889 s, training loss: 0.6028
# Iteration: 600, Time: 431.9299 s, training loss: 0.6201
# Iteration: 650, Time: 467.7073 s, training loss: 0.5917
# Iteration: 700, Time: 503.3380 s, training loss: 0.6307
# Iteration: 750, Time: 539.0682 s, training loss: 0.5759
# Iteration: 800, Time: 575.1360 s, training loss: 0.4577
# Iteration: 850, Time: 611.0095 s, training loss: 0.5043
# Iteration: 900, Time: 646.5593 s, training loss: 0.5275
# Iteration: 950, Time: 682.4910 s, training loss: 0.5434
# Iteration: 1000, Time: 718.7362 s, training loss: 0.4830
# Iteration: 1050, Time: 754.9023 s, training loss: 0.4414
# Iteration: 1100, Time: 790.7433 s, training loss: 0.4226
# Iteration: 1150, Time: 825.9713 s, training loss: 0.4501
# Iteration: 1200, Time: 861.6440 s, training loss: 0.5402
# Iteration: 1250, Time: 897.4103 s, training loss: 0.3542
# Iteration: 1300, Time: 933.0910 s, training loss: 0.3664
# Iteration: 1350, Time: 969.0204 s, training loss: 0.3728
# Iteration: 1400, Time: 1004.5261 s, training loss: 0.3511
# Iteration: 1450, Time: 1040.3447 s, training loss: 0.3192
# Iteration: 1500, Time: 1076.8039 s, training loss: 0.3319
# Iteration: 1550, Time: 1112.9998 s, training loss: 0.4009
# Iteration: 1600, Time: 1149.4926 s, training loss: 0.3474
# Iteration: 1650, Time: 1185.7471 s, training loss: 0.3342
# -----EPOCH1----- done.  Validation loss:  0.2538804708203921
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH2-----
# Iteration: 1700, Time: 1276.0667 s, training loss: 0.1849
# Iteration: 1750, Time: 1309.4028 s, training loss: 0.2005
# Iteration: 1800, Time: 1343.2094 s, training loss: 0.2662
# Iteration: 1850, Time: 1376.8926 s, training loss: 0.2459
# Iteration: 1900, Time: 1410.5392 s, training loss: 0.2735
# Iteration: 1950, Time: 1444.5384 s, training loss: 0.2353
# Iteration: 2000, Time: 1478.1008 s, training loss: 0.2571
# Iteration: 2050, Time: 1511.7248 s, training loss: 0.3082
# Iteration: 2100, Time: 1545.3942 s, training loss: 0.2866
# Iteration: 2150, Time: 1579.1498 s, training loss: 0.3312
# Iteration: 2200, Time: 1613.1288 s, training loss: 0.2366
# Iteration: 2250, Time: 1647.2096 s, training loss: 0.2533
# Iteration: 2300, Time: 1680.9486 s, training loss: 0.1966
# Iteration: 2350, Time: 1714.4010 s, training loss: 0.2815
# Iteration: 2400, Time: 1747.9321 s, training loss: 0.2240
# Iteration: 2450, Time: 1781.5940 s, training loss: 0.2868
# Iteration: 2500, Time: 1815.6874 s, training loss: 0.2201
# Iteration: 2550, Time: 1849.7979 s, training loss: 0.2045
# Iteration: 2600, Time: 1883.4493 s, training loss: 0.1370
# Iteration: 2650, Time: 1917.1113 s, training loss: 0.2072
# Iteration: 2700, Time: 1950.8550 s, training loss: 0.1867
# Iteration: 2750, Time: 1985.3764 s, training loss: 0.2139
# Iteration: 2800, Time: 2019.8204 s, training loss: 0.2312
# Iteration: 2850, Time: 2053.8738 s, training loss: 0.2352
# Iteration: 2900, Time: 2087.7639 s, training loss: 0.2270
# Iteration: 2950, Time: 2121.7088 s, training loss: 0.2517
# Iteration: 3000, Time: 2155.3379 s, training loss: 0.2495
# Iteration: 3050, Time: 2189.4380 s, training loss: 0.1618
# Iteration: 3100, Time: 2223.4353 s, training loss: 0.1946
# Iteration: 3150, Time: 2257.6820 s, training loss: 0.2368
# Iteration: 3200, Time: 2291.3711 s, training loss: 0.2008
# Iteration: 3250, Time: 2325.2010 s, training loss: 0.2228
# Iteration: 3300, Time: 2358.9699 s, training loss: 0.1874
# -----EPOCH2----- done.  Validation loss:  0.250903084947256
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH3-----
# Iteration: 3350, Time: 2438.9482 s, training loss: 0.1882
# Iteration: 3400, Time: 2472.6057 s, training loss: 0.1594
# Iteration: 3450, Time: 2506.5027 s, training loss: 0.1578
# Iteration: 3500, Time: 2540.3466 s, training loss: 0.1454
# Iteration: 3550, Time: 2573.7125 s, training loss: 0.2078
# Iteration: 3600, Time: 2606.9419 s, training loss: 0.2169
# Iteration: 3650, Time: 2640.8245 s, training loss: 0.1217
# Iteration: 3700, Time: 2675.0653 s, training loss: 0.1966
# Iteration: 3750, Time: 2709.2052 s, training loss: 0.1355
# Iteration: 3800, Time: 2743.5591 s, training loss: 0.1728
# Iteration: 3850, Time: 2777.2743 s, training loss: 0.1699
# Iteration: 3900, Time: 2811.2258 s, training loss: 0.1650
# Iteration: 3950, Time: 2845.4004 s, training loss: 0.1600
# Iteration: 4000, Time: 2879.7330 s, training loss: 0.1516
# Iteration: 4050, Time: 2914.4346 s, training loss: 0.1668
# Iteration: 4100, Time: 2948.3072 s, training loss: 0.2056
# Iteration: 4150, Time: 2982.3425 s, training loss: 0.1703
# Iteration: 4200, Time: 3016.1499 s, training loss: 0.1419
# Iteration: 4250, Time: 3050.8921 s, training loss: 0.1205
# Iteration: 4300, Time: 3085.2296 s, training loss: 0.1702
# Iteration: 4350, Time: 3119.6665 s, training loss: 0.1792
# Iteration: 4400, Time: 3153.7196 s, training loss: 0.1123
# Iteration: 4450, Time: 3187.4647 s, training loss: 0.1782
# Iteration: 4500, Time: 3221.2571 s, training loss: 0.1558
# Iteration: 4550, Time: 3255.7881 s, training loss: 0.1566
# Iteration: 4600, Time: 3290.4236 s, training loss: 0.1139
# Iteration: 4650, Time: 3325.0568 s, training loss: 0.1574
# Iteration: 4700, Time: 3359.5545 s, training loss: 0.1405
# Iteration: 4750, Time: 3393.4549 s, training loss: 0.1455
# Iteration: 4800, Time: 3427.8036 s, training loss: 0.1226
# Iteration: 4850, Time: 3462.5255 s, training loss: 0.1351
# Iteration: 4900, Time: 3497.3804 s, training loss: 0.1708
# Iteration: 4950, Time: 3532.1635 s, training loss: 0.1663
# -----EPOCH3----- done.  Validation loss:  0.16275069697965389
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH4-----
# Iteration: 5000, Time: 3615.6762 s, training loss: 0.1286
# Iteration: 5050, Time: 3649.8497 s, training loss: 0.1431
# Iteration: 5100, Time: 3683.5269 s, training loss: 0.1022
# Iteration: 5150, Time: 3717.1508 s, training loss: 0.1384
# Iteration: 5200, Time: 3750.7271 s, training loss: 0.1548
# Iteration: 5250, Time: 3784.7913 s, training loss: 0.1303
# Iteration: 5300, Time: 3818.7003 s, training loss: 0.1299
# Iteration: 5350, Time: 3852.9096 s, training loss: 0.1369
# Iteration: 5400, Time: 3886.2075 s, training loss: 0.1280
# Iteration: 5450, Time: 3919.8757 s, training loss: 0.0895
# Iteration: 5500, Time: 3953.9098 s, training loss: 0.1476
# Iteration: 5550, Time: 3988.3452 s, training loss: 0.1137
# Iteration: 5600, Time: 4022.3011 s, training loss: 0.0826
# Iteration: 5650, Time: 4056.0318 s, training loss: 0.1049
# Iteration: 5700, Time: 4089.5081 s, training loss: 0.1307
# Iteration: 5750, Time: 4122.6979 s, training loss: 0.1317
# Iteration: 5800, Time: 4156.3789 s, training loss: 0.1303
# Iteration: 5850, Time: 4190.2939 s, training loss: 0.1104
# Iteration: 5900, Time: 4224.1665 s, training loss: 0.0882
# Iteration: 5950, Time: 4257.7004 s, training loss: 0.0825
# Iteration: 6000, Time: 4290.9417 s, training loss: 0.1009
# Iteration: 6050, Time: 4324.4622 s, training loss: 0.1290
# Iteration: 6100, Time: 4357.9782 s, training loss: 0.1055
# Iteration: 6150, Time: 4391.9997 s, training loss: 0.1140
# Iteration: 6200, Time: 4425.6566 s, training loss: 0.1195
# Iteration: 6250, Time: 4459.5472 s, training loss: 0.0857
# Iteration: 6300, Time: 4493.1152 s, training loss: 0.1591
# Iteration: 6350, Time: 4526.8477 s, training loss: 0.1368
# Iteration: 6400, Time: 4560.4232 s, training loss: 0.1221
# Iteration: 6450, Time: 4593.9509 s, training loss: 0.1517
# Iteration: 6500, Time: 4627.7362 s, training loss: 0.1549
# Iteration: 6550, Time: 4661.5516 s, training loss: 0.1121
# Iteration: 6600, Time: 4695.4088 s, training loss: 0.1179
# -----EPOCH4----- done.  Validation loss:  0.1716528372080073
# -----EPOCH5-----
# Iteration: 6650, Time: 4768.6332 s, training loss: 0.0662
# Iteration: 6700, Time: 4802.2727 s, training loss: 0.0999
# Iteration: 6750, Time: 4836.0252 s, training loss: 0.0920
# Iteration: 6800, Time: 4870.1203 s, training loss: 0.0822
# Iteration: 6850, Time: 4904.1181 s, training loss: 0.0864
# Iteration: 6900, Time: 4937.9800 s, training loss: 0.1025
# Iteration: 6950, Time: 4971.7771 s, training loss: 0.0773
# Iteration: 7000, Time: 5005.5474 s, training loss: 0.1053
# Iteration: 7050, Time: 5039.5627 s, training loss: 0.0869
# Iteration: 7100, Time: 5074.0004 s, training loss: 0.0735
# Iteration: 7150, Time: 5108.5671 s, training loss: 0.0681
# Iteration: 7200, Time: 5142.9097 s, training loss: 0.1208
# Iteration: 7250, Time: 5176.8566 s, training loss: 0.1141
# Iteration: 7300, Time: 5210.8899 s, training loss: 0.0970
# Iteration: 7350, Time: 5244.8350 s, training loss: 0.0950
# Iteration: 7400, Time: 5279.1790 s, training loss: 0.0989
# Iteration: 7450, Time: 5313.5261 s, training loss: 0.0903
# Iteration: 7500, Time: 5347.9259 s, training loss: 0.1129
# Iteration: 7550, Time: 5381.6339 s, training loss: 0.1064
# Iteration: 7600, Time: 5415.3053 s, training loss: 0.0803
# Iteration: 7650, Time: 5449.5783 s, training loss: 0.0739
# Iteration: 7700, Time: 5483.5998 s, training loss: 0.1286
# Iteration: 7750, Time: 5518.1030 s, training loss: 0.0799
# Iteration: 7800, Time: 5551.9483 s, training loss: 0.0795
# Iteration: 7850, Time: 5586.0762 s, training loss: 0.0957
# Iteration: 7900, Time: 5620.1192 s, training loss: 0.0994
# Iteration: 7950, Time: 5654.8139 s, training loss: 0.1232
# Iteration: 8000, Time: 5689.2508 s, training loss: 0.0801
# Iteration: 8050, Time: 5723.7419 s, training loss: 0.0817
# Iteration: 8100, Time: 5758.1439 s, training loss: 0.0748
# Iteration: 8150, Time: 5791.8775 s, training loss: 0.0696
# Iteration: 8200, Time: 5826.4220 s, training loss: 0.0941
# Iteration: 8250, Time: 5860.8918 s, training loss: 0.0992
# -----EPOCH5----- done.  Validation loss:  0.14230655745536575
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH6-----
# Iteration: 8300, Time: 5942.0173 s, training loss: 0.1028
# Iteration: 8350, Time: 5975.6671 s, training loss: 0.0859
# Iteration: 8400, Time: 6009.8058 s, training loss: 0.0673
# Iteration: 8450, Time: 6043.6108 s, training loss: 0.0620
# Iteration: 8500, Time: 6077.0556 s, training loss: 0.0609
# Iteration: 8550, Time: 6110.3026 s, training loss: 0.0573
# Iteration: 8600, Time: 6143.9079 s, training loss: 0.0669
# Iteration: 8650, Time: 6177.7243 s, training loss: 0.0744
# Iteration: 8700, Time: 6211.7227 s, training loss: 0.0978
# Iteration: 8750, Time: 6245.3798 s, training loss: 0.0645
# Iteration: 8800, Time: 6278.7469 s, training loss: 0.1214
# Iteration: 8850, Time: 6312.0904 s, training loss: 0.0787
# Iteration: 8900, Time: 6345.8078 s, training loss: 0.0964
# Iteration: 8950, Time: 6379.6357 s, training loss: 0.0582
# Iteration: 9000, Time: 6413.6419 s, training loss: 0.0842
# Iteration: 9050, Time: 6447.3471 s, training loss: 0.0813
# Iteration: 9100, Time: 6480.5834 s, training loss: 0.0590
# Iteration: 9150, Time: 6513.9224 s, training loss: 0.0544
# Iteration: 9200, Time: 6547.9180 s, training loss: 0.0957
# Iteration: 9250, Time: 6581.5254 s, training loss: 0.0764
# Iteration: 9300, Time: 6615.5370 s, training loss: 0.0732
# Iteration: 9350, Time: 6649.2342 s, training loss: 0.0727
# Iteration: 9400, Time: 6682.7760 s, training loss: 0.1015
# Iteration: 9450, Time: 6716.2608 s, training loss: 0.0674
# Iteration: 9500, Time: 6749.9107 s, training loss: 0.0553
# Iteration: 9550, Time: 6783.6467 s, training loss: 0.0694
# Iteration: 9600, Time: 6817.7026 s, training loss: 0.0835
# Iteration: 9650, Time: 6851.0485 s, training loss: 0.0693
# Iteration: 9700, Time: 6884.6751 s, training loss: 0.0823
# Iteration: 9750, Time: 6918.2902 s, training loss: 0.0674
# Iteration: 9800, Time: 6952.5464 s, training loss: 0.0868
# Iteration: 9850, Time: 6986.4782 s, training loss: 0.0925
# Iteration: 9900, Time: 7020.4904 s, training loss: 0.0695
# -----EPOCH6----- done.  Validation loss:  0.13997518114410043
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH7-----
# Iteration: 9950, Time: 7101.6387 s, training loss: 0.0692
# Iteration: 10000, Time: 7135.1947 s, training loss: 0.0513
# Iteration: 10050, Time: 7168.1291 s, training loss: 0.0381
# Iteration: 10100, Time: 7201.6843 s, training loss: 0.0410
# Iteration: 10150, Time: 7235.2060 s, training loss: 0.0543
# Iteration: 10200, Time: 7269.0738 s, training loss: 0.0670
# Iteration: 10250, Time: 7302.9535 s, training loss: 0.0508
# Iteration: 10300, Time: 7336.7067 s, training loss: 0.0638
# Iteration: 10350, Time: 7370.2980 s, training loss: 0.0637
# Iteration: 10400, Time: 7403.3685 s, training loss: 0.0723
# Iteration: 10450, Time: 7437.3670 s, training loss: 0.0760
# Iteration: 10500, Time: 7471.3561 s, training loss: 0.0639
# Iteration: 10550, Time: 7505.2970 s, training loss: 0.0660
# Iteration: 10600, Time: 7539.1808 s, training loss: 0.0714
# Iteration: 10650, Time: 7572.9720 s, training loss: 0.0348
# Iteration: 10700, Time: 7606.3528 s, training loss: 0.0699
# Iteration: 10750, Time: 7640.1998 s, training loss: 0.0592
# Iteration: 10800, Time: 7673.7873 s, training loss: 0.0428
# Iteration: 10850, Time: 7707.8608 s, training loss: 0.0436
# Iteration: 10900, Time: 7741.9235 s, training loss: 0.0427
# Iteration: 10950, Time: 7775.4397 s, training loss: 0.0552
# Iteration: 11000, Time: 7809.1145 s, training loss: 0.0793
# Iteration: 11050, Time: 7842.9122 s, training loss: 0.0574
# Iteration: 11100, Time: 7877.0567 s, training loss: 0.0660
# Iteration: 11150, Time: 7911.3607 s, training loss: 0.0479
# Iteration: 11200, Time: 7945.8555 s, training loss: 0.0511
# Iteration: 11250, Time: 7979.3648 s, training loss: 0.0685
# Iteration: 11300, Time: 8013.4886 s, training loss: 0.0560
# Iteration: 11350, Time: 8047.4706 s, training loss: 0.0540
# Iteration: 11400, Time: 8081.7869 s, training loss: 0.0381
# Iteration: 11450, Time: 8116.4205 s, training loss: 0.0495
# Iteration: 11500, Time: 8150.5328 s, training loss: 0.0553
# Iteration: 11550, Time: 8184.6871 s, training loss: 0.0773
# -----EPOCH7----- done.  Validation loss:  0.13161276541451525
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH8-----
# Iteration: 11600, Time: 8265.4923 s, training loss: 0.0564
# Iteration: 11650, Time: 8298.9052 s, training loss: 0.0508
# Iteration: 11700, Time: 8332.4777 s, training loss: 0.0325
# Iteration: 11750, Time: 8365.9885 s, training loss: 0.0361
# Iteration: 11800, Time: 8399.6357 s, training loss: 0.0664
# Iteration: 11850, Time: 8433.7021 s, training loss: 0.0466
# Iteration: 11900, Time: 8467.0595 s, training loss: 0.0404
# Iteration: 11950, Time: 8500.4004 s, training loss: 0.0599
# Iteration: 12000, Time: 8534.1088 s, training loss: 0.0556
# Iteration: 12050, Time: 8567.8100 s, training loss: 0.0652
# Iteration: 12100, Time: 8601.7675 s, training loss: 0.0550
# Iteration: 12150, Time: 8635.8210 s, training loss: 0.0414
# Iteration: 12200, Time: 8669.4063 s, training loss: 0.0462
# Iteration: 12250, Time: 8702.7423 s, training loss: 0.0355
# Iteration: 12300, Time: 8736.6282 s, training loss: 0.0610
# Iteration: 12350, Time: 8770.4601 s, training loss: 0.0417
# Iteration: 12400, Time: 8804.1426 s, training loss: 0.0386
# Iteration: 12450, Time: 8837.7653 s, training loss: 0.0429
# Iteration: 12500, Time: 8871.2971 s, training loss: 0.0444
# Iteration: 12550, Time: 8904.5825 s, training loss: 0.0674
# Iteration: 12600, Time: 8938.5784 s, training loss: 0.0489
# Iteration: 12650, Time: 8972.7467 s, training loss: 0.0507
# Iteration: 12700, Time: 9006.6646 s, training loss: 0.0291
# Iteration: 12750, Time: 9040.4414 s, training loss: 0.0406
# Iteration: 12800, Time: 9074.0104 s, training loss: 0.0578
# Iteration: 12850, Time: 9107.6745 s, training loss: 0.0241
# Iteration: 12900, Time: 9141.7442 s, training loss: 0.0452
# Iteration: 12950, Time: 9175.7396 s, training loss: 0.0389
# Iteration: 13000, Time: 9209.6984 s, training loss: 0.0388
# Iteration: 13050, Time: 9243.6380 s, training loss: 0.0300
# Iteration: 13100, Time: 9277.5286 s, training loss: 0.0415
# Iteration: 13150, Time: 9311.1813 s, training loss: 0.0563
# Iteration: 13200, Time: 9345.6033 s, training loss: 0.0384
# -----EPOCH8----- done.  Validation loss:  0.09195308165123348
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH9-----
# Iteration: 13250, Time: 9426.4714 s, training loss: 0.0281
# Iteration: 13300, Time: 9460.3558 s, training loss: 0.0558
# Iteration: 13350, Time: 9494.2591 s, training loss: 0.0419
# Iteration: 13400, Time: 9527.9925 s, training loss: 0.0524
# Iteration: 13450, Time: 9561.5818 s, training loss: 0.0497
# Iteration: 13500, Time: 9595.0142 s, training loss: 0.0491
# Iteration: 13550, Time: 9628.8201 s, training loss: 0.0312
# Iteration: 13600, Time: 9662.6494 s, training loss: 0.0274
# Iteration: 13650, Time: 9696.6100 s, training loss: 0.0582
# Iteration: 13700, Time: 9730.6023 s, training loss: 0.0203
# Iteration: 13750, Time: 9763.7566 s, training loss: 0.0444
# Iteration: 13800, Time: 9797.0452 s, training loss: 0.0312
# Iteration: 13850, Time: 9830.8806 s, training loss: 0.0478
# Iteration: 13900, Time: 9864.5584 s, training loss: 0.0309
# Iteration: 13950, Time: 9898.1413 s, training loss: 0.0480
# Iteration: 14000, Time: 9931.7194 s, training loss: 0.0278
# Iteration: 14050, Time: 9965.2237 s, training loss: 0.0263
# Iteration: 14100, Time: 9998.6839 s, training loss: 0.0414
# Iteration: 14150, Time: 10032.5216 s, training loss: 0.0656
# Iteration: 14200, Time: 10066.4821 s, training loss: 0.0444
# Iteration: 14250, Time: 10100.8348 s, training loss: 0.0484
# Iteration: 14300, Time: 10134.9323 s, training loss: 0.0347
# Iteration: 14350, Time: 10168.2501 s, training loss: 0.0397
# Iteration: 14400, Time: 10201.7859 s, training loss: 0.0452
# Iteration: 14450, Time: 10235.4136 s, training loss: 0.0414
# Iteration: 14500, Time: 10269.3361 s, training loss: 0.0309
# Iteration: 14550, Time: 10303.5081 s, training loss: 0.0279
# Iteration: 14600, Time: 10337.3649 s, training loss: 0.0497
# Iteration: 14650, Time: 10370.8469 s, training loss: 0.0388
# Iteration: 14700, Time: 10404.5268 s, training loss: 0.0388
# Iteration: 14750, Time: 10438.5563 s, training loss: 0.0461
# Iteration: 14800, Time: 10472.7994 s, training loss: 0.0372
# Iteration: 14850, Time: 10507.0734 s, training loss: 0.0343
# -----EPOCH9----- done.  Validation loss:  0.07914252269545939
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH10-----
# Iteration: 14900, Time: 10587.6982 s, training loss: 0.0344
# Iteration: 14950, Time: 10621.6181 s, training loss: 0.0297
# Iteration: 15000, Time: 10655.3770 s, training loss: 0.0442
# Iteration: 15050, Time: 10689.0170 s, training loss: 0.0539
# Iteration: 15100, Time: 10722.5446 s, training loss: 0.0268
# Iteration: 15150, Time: 10756.1087 s, training loss: 0.0209
# Iteration: 15200, Time: 10789.5704 s, training loss: 0.0473
# Iteration: 15250, Time: 10822.9961 s, training loss: 0.0376
# Iteration: 15300, Time: 10856.3479 s, training loss: 0.0421
# Iteration: 15350, Time: 10889.8319 s, training loss: 0.0198
# Iteration: 15400, Time: 10923.3158 s, training loss: 0.0406
# Iteration: 15450, Time: 10956.7063 s, training loss: 0.0243
# Iteration: 15500, Time: 10990.4576 s, training loss: 0.0292
# Iteration: 15550, Time: 11024.2135 s, training loss: 0.0381
# Iteration: 15600, Time: 11057.3985 s, training loss: 0.0240
# Iteration: 15650, Time: 11090.9235 s, training loss: 0.0373
# Iteration: 15700, Time: 11124.5039 s, training loss: 0.0387
# Iteration: 15750, Time: 11158.3127 s, training loss: 0.0195
# Iteration: 15800, Time: 11192.1561 s, training loss: 0.0202
# Iteration: 15850, Time: 11226.0262 s, training loss: 0.0406
# Iteration: 15900, Time: 11259.3332 s, training loss: 0.0390
# Iteration: 15950, Time: 11292.8876 s, training loss: 0.0250
# Iteration: 16000, Time: 11326.5638 s, training loss: 0.0228
# Iteration: 16050, Time: 11360.5262 s, training loss: 0.0672
# Iteration: 16100, Time: 11394.5981 s, training loss: 0.0323
# Iteration: 16150, Time: 11428.9471 s, training loss: 0.0427
# Iteration: 16200, Time: 11462.9519 s, training loss: 0.0402
# Iteration: 16250, Time: 11496.7292 s, training loss: 0.0331
# Iteration: 16300, Time: 11530.5727 s, training loss: 0.0445
# Iteration: 16350, Time: 11564.8558 s, training loss: 0.0140
# Iteration: 16400, Time: 11599.0851 s, training loss: 0.0459
# Iteration: 16450, Time: 11633.7340 s, training loss: 0.0452
# Iteration: 16500, Time: 11667.8080 s, training loss: 0.0427
# -----EPOCH10----- done.  Validation loss:  0.08142774982151779
# -----EPOCH11-----
# Iteration: 16550, Time: 11741.0281 s, training loss: 0.0272
# Iteration: 16600, Time: 11774.6047 s, training loss: 0.0402
# Iteration: 16650, Time: 11807.6206 s, training loss: 0.0192
# Iteration: 16700, Time: 11841.3071 s, training loss: 0.0679
# Iteration: 16750, Time: 11875.0183 s, training loss: 0.0203
# Iteration: 16800, Time: 11908.6823 s, training loss: 0.0437
# Iteration: 16850, Time: 11941.9470 s, training loss: 0.0375
# Iteration: 16900, Time: 11975.3978 s, training loss: 0.0251
# Iteration: 16950, Time: 12008.6034 s, training loss: 0.0339
# Iteration: 17000, Time: 12042.1170 s, training loss: 0.0350
# Iteration: 17050, Time: 12076.1003 s, training loss: 0.0327
# Iteration: 17100, Time: 12109.7885 s, training loss: 0.0206
# Iteration: 17150, Time: 12143.3307 s, training loss: 0.0292
# Iteration: 17200, Time: 12176.9562 s, training loss: 0.0314
# Iteration: 17250, Time: 12210.4402 s, training loss: 0.0319
# Iteration: 17300, Time: 12243.9941 s, training loss: 0.0365
# Iteration: 17350, Time: 12277.6299 s, training loss: 0.0381
# Iteration: 17400, Time: 12311.4196 s, training loss: 0.0224
# Iteration: 17450, Time: 12344.9835 s, training loss: 0.0422
# Iteration: 17500, Time: 12378.4269 s, training loss: 0.0194
# Iteration: 17550, Time: 12412.1757 s, training loss: 0.0387
# Iteration: 17600, Time: 12446.1891 s, training loss: 0.0362
# Iteration: 17650, Time: 12480.2772 s, training loss: 0.0435
# Iteration: 17700, Time: 12514.2405 s, training loss: 0.0354
# Iteration: 17750, Time: 12547.4431 s, training loss: 0.0374
# Iteration: 17800, Time: 12580.9582 s, training loss: 0.0271
# Iteration: 17850, Time: 12614.4933 s, training loss: 0.0313
# Iteration: 17900, Time: 12648.2025 s, training loss: 0.0247
# Iteration: 17950, Time: 12681.9298 s, training loss: 0.0404
# Iteration: 18000, Time: 12715.8544 s, training loss: 0.0311
# Iteration: 18050, Time: 12749.3325 s, training loss: 0.0328
# Iteration: 18100, Time: 12782.7143 s, training loss: 0.0410
# Iteration: 18150, Time: 12816.1356 s, training loss: 0.0197
# -----EPOCH11----- done.  Validation loss:  0.08057627961739809
# -----EPOCH12-----
# Iteration: 18200, Time: 12889.3130 s, training loss: 0.0294
# Iteration: 18250, Time: 12922.7649 s, training loss: 0.0276
# Iteration: 18300, Time: 12956.7133 s, training loss: 0.0424
# Iteration: 18350, Time: 12990.0684 s, training loss: 0.0259
# Iteration: 18400, Time: 13023.3750 s, training loss: 0.0353
# Iteration: 18450, Time: 13056.6097 s, training loss: 0.0321
# Iteration: 18500, Time: 13089.9615 s, training loss: 0.0421
# Iteration: 18550, Time: 13123.7821 s, training loss: 0.0301
# Iteration: 18600, Time: 13157.6902 s, training loss: 0.0525
# Iteration: 18650, Time: 13191.5959 s, training loss: 0.0306
# Iteration: 18700, Time: 13225.0554 s, training loss: 0.0494
# Iteration: 18750, Time: 13258.2351 s, training loss: 0.0231
# Iteration: 18800, Time: 13291.5311 s, training loss: 0.0421
# Iteration: 18850, Time: 13325.5281 s, training loss: 0.0581
# Iteration: 18900, Time: 13359.4624 s, training loss: 0.0393
# Iteration: 18950, Time: 13393.6463 s, training loss: 0.0280
# Iteration: 19000, Time: 13427.0564 s, training loss: 0.0505
# Iteration: 19050, Time: 13460.5092 s, training loss: 0.0463
# Iteration: 19100, Time: 13494.1704 s, training loss: 0.0352
# Iteration: 19150, Time: 13527.9345 s, training loss: 0.0229
# Iteration: 19200, Time: 13561.9280 s, training loss: 0.0536
# Iteration: 19250, Time: 13595.8774 s, training loss: 0.0261
# Iteration: 19300, Time: 13629.3041 s, training loss: 0.0301
# Iteration: 19350, Time: 13662.6854 s, training loss: 0.0162
# Iteration: 19400, Time: 13696.5831 s, training loss: 0.0390
# Iteration: 19450, Time: 13730.4103 s, training loss: 0.0305
# Iteration: 19500, Time: 13764.4348 s, training loss: 0.0366
# Iteration: 19550, Time: 13798.4592 s, training loss: 0.0354
# Iteration: 19600, Time: 13832.0929 s, training loss: 0.0425
# Iteration: 19650, Time: 13865.6160 s, training loss: 0.0302
# Iteration: 19700, Time: 13899.1383 s, training loss: 0.0301
# Iteration: 19750, Time: 13933.6004 s, training loss: 0.0310
# Iteration: 19800, Time: 13967.8538 s, training loss: 0.0319
# -----EPOCH12----- done.  Validation loss:  0.08745215945284879
# -----EPOCH13-----
# Iteration: 19850, Time: 14041.6412 s, training loss: 0.0352
# Iteration: 19900, Time: 14075.7197 s, training loss: 0.0376
# Iteration: 19950, Time: 14109.7853 s, training loss: 0.0565
# Iteration: 20000, Time: 14143.0839 s, training loss: 0.0329
# Iteration: 20050, Time: 14176.8452 s, training loss: 0.0300
# Iteration: 20100, Time: 14210.9166 s, training loss: 0.0327
# Iteration: 20150, Time: 14245.0034 s, training loss: 0.0473
# Iteration: 20200, Time: 14279.1699 s, training loss: 0.0217
# Iteration: 20250, Time: 14312.9543 s, training loss: 0.0321
# Iteration: 20300, Time: 14346.4419 s, training loss: 0.0188
# Iteration: 20350, Time: 14380.1215 s, training loss: 0.0436
# Iteration: 20400, Time: 14413.7483 s, training loss: 0.0180
# Iteration: 20450, Time: 14447.8533 s, training loss: 0.0241
# Iteration: 20500, Time: 14481.7690 s, training loss: 0.0467
# Iteration: 20550, Time: 14515.4733 s, training loss: 0.0259
# Iteration: 20600, Time: 14548.8056 s, training loss: 0.0395
# Iteration: 20650, Time: 14582.5665 s, training loss: 0.0484
# Iteration: 20700, Time: 14616.3576 s, training loss: 0.0305
# Iteration: 20750, Time: 14650.6783 s, training loss: 0.0081
# Iteration: 20800, Time: 14684.8128 s, training loss: 0.0229
# Iteration: 20850, Time: 14718.8276 s, training loss: 0.0294
# Iteration: 20900, Time: 14752.3812 s, training loss: 0.0380
# Iteration: 20950, Time: 14785.8783 s, training loss: 0.0346
# Iteration: 21000, Time: 14820.0986 s, training loss: 0.0237
# Iteration: 21050, Time: 14853.9222 s, training loss: 0.0251
# Iteration: 21100, Time: 14887.8278 s, training loss: 0.0342
# Iteration: 21150, Time: 14921.2894 s, training loss: 0.0507
# Iteration: 21200, Time: 14954.8149 s, training loss: 0.0422
# Iteration: 21250, Time: 14988.1833 s, training loss: 0.0429
# Iteration: 21300, Time: 15021.9120 s, training loss: 0.0220
# Iteration: 21350, Time: 15055.6166 s, training loss: 0.0168
# Iteration: 21400, Time: 15089.4173 s, training loss: 0.0495
# Iteration: 21450, Time: 15123.3466 s, training loss: 0.0296
# -----EPOCH13----- done.  Validation loss:  0.09869128122752148
# -----EPOCH14-----
# Iteration: 21500, Time: 15195.9456 s, training loss: 0.0132
# Iteration: 21550, Time: 15229.3844 s, training loss: 0.0512
# Iteration: 21600, Time: 15262.8991 s, training loss: 0.0284
# Iteration: 21650, Time: 15296.3951 s, training loss: 0.0383
# Iteration: 21700, Time: 15330.1780 s, training loss: 0.0411
# Iteration: 21750, Time: 15364.0174 s, training loss: 0.0470
# Iteration: 21800, Time: 15397.4852 s, training loss: 0.0390
# Iteration: 21850, Time: 15431.0916 s, training loss: 0.0499
# Iteration: 21900, Time: 15464.8520 s, training loss: 0.0326
# Iteration: 21950, Time: 15498.8528 s, training loss: 0.0171
# Iteration: 22000, Time: 15532.8796 s, training loss: 0.0265
# Iteration: 22050, Time: 15567.0887 s, training loss: 0.0246
# Iteration: 22100, Time: 15601.3697 s, training loss: 0.0290
# Iteration: 22150, Time: 15635.0560 s, training loss: 0.0277
# Iteration: 22200, Time: 15668.5242 s, training loss: 0.0399
# Iteration: 22250, Time: 15702.6775 s, training loss: 0.0479
# Iteration: 22300, Time: 15737.0755 s, training loss: 0.0370
# Iteration: 22350, Time: 15771.3648 s, training loss: 0.0320
# Iteration: 22400, Time: 15805.4135 s, training loss: 0.0240
# Iteration: 22450, Time: 15839.3016 s, training loss: 0.0363
# Iteration: 22500, Time: 15872.9415 s, training loss: 0.0213
# Iteration: 22550, Time: 15906.8302 s, training loss: 0.0233
# Iteration: 22600, Time: 15941.1715 s, training loss: 0.0345
# Iteration: 22650, Time: 15975.9199 s, training loss: 0.0461
# Iteration: 22700, Time: 16010.3942 s, training loss: 0.0315
# Iteration: 22750, Time: 16044.5420 s, training loss: 0.0175
# Iteration: 22800, Time: 16078.5131 s, training loss: 0.0450
# Iteration: 22850, Time: 16113.2365 s, training loss: 0.0314
# Iteration: 22900, Time: 16148.1645 s, training loss: 0.0288
# Iteration: 22950, Time: 16182.5868 s, training loss: 0.0341
# Iteration: 23000, Time: 16217.1288 s, training loss: 0.0344
# Iteration: 23050, Time: 16251.2322 s, training loss: 0.0281
# Iteration: 23100, Time: 16285.5360 s, training loss: 0.0290
# -----EPOCH14----- done.  Validation loss:  0.0863868485350134
# -----EPOCH15-----
# Iteration: 23150, Time: 16358.8691 s, training loss: 0.0363
# Iteration: 23200, Time: 16392.3432 s, training loss: 0.0258
# Iteration: 23250, Time: 16426.6879 s, training loss: 0.0389
# Iteration: 23300, Time: 16460.5740 s, training loss: 0.0343
# Iteration: 23350, Time: 16494.3298 s, training loss: 0.0339
# Iteration: 23400, Time: 16527.9247 s, training loss: 0.0301
# Iteration: 23450, Time: 16561.1544 s, training loss: 0.0293
# Iteration: 23500, Time: 16594.9725 s, training loss: 0.0212
# Iteration: 23550, Time: 16628.8051 s, training loss: 0.0356
# Iteration: 23600, Time: 16662.8899 s, training loss: 0.0366
# Iteration: 23650, Time: 16696.4880 s, training loss: 0.0455
# Iteration: 23700, Time: 16729.9536 s, training loss: 0.0288
# Iteration: 23750, Time: 16763.3587 s, training loss: 0.0432
# Iteration: 23800, Time: 16797.0381 s, training loss: 0.0232
# Iteration: 23850, Time: 16830.8794 s, training loss: 0.0351
# Iteration: 23900, Time: 16864.6814 s, training loss: 0.0347
# Iteration: 23950, Time: 16898.5792 s, training loss: 0.0343
# Iteration: 24000, Time: 16931.8823 s, training loss: 0.0402
# Iteration: 24050, Time: 16965.2476 s, training loss: 0.0105
# Iteration: 24100, Time: 16999.1168 s, training loss: 0.0388
# Iteration: 24150, Time: 17032.9901 s, training loss: 0.0463
# Iteration: 24200, Time: 17066.7634 s, training loss: 0.0405
# Iteration: 24250, Time: 17100.5413 s, training loss: 0.0232
# Iteration: 24300, Time: 17134.0938 s, training loss: 0.0213
# Iteration: 24350, Time: 17167.5242 s, training loss: 0.0278
# Iteration: 24400, Time: 17200.7235 s, training loss: 0.0395
# Iteration: 24450, Time: 17234.1071 s, training loss: 0.0359
# Iteration: 24500, Time: 17267.5604 s, training loss: 0.0448
# Iteration: 24550, Time: 17301.4057 s, training loss: 0.0308
# Iteration: 24600, Time: 17334.8961 s, training loss: 0.0447
# Iteration: 24650, Time: 17368.1770 s, training loss: 0.0316
# Iteration: 24700, Time: 17401.4270 s, training loss: 0.0460
# Iteration: 24750, Time: 17434.8263 s, training loss: 0.0520
# -----EPOCH15----- done.  Validation loss:  0.09361673912343747
# -----EPOCH16-----
# Iteration: 24800, Time: 17507.6630 s, training loss: 0.0359
# Iteration: 24850, Time: 17541.5092 s, training loss: 0.0264
# Iteration: 24900, Time: 17575.6259 s, training loss: 0.0208
# Iteration: 24950, Time: 17609.2089 s, training loss: 0.0376
# Iteration: 25000, Time: 17642.3138 s, training loss: 0.0468
# Iteration: 25050, Time: 17675.6795 s, training loss: 0.0230
# Iteration: 25100, Time: 17709.1668 s, training loss: 0.0388
# Iteration: 25150, Time: 17743.0650 s, training loss: 0.0296
# Iteration: 25200, Time: 17776.9959 s, training loss: 0.0281
# Iteration: 25250, Time: 17810.7357 s, training loss: 0.0344
# Iteration: 25300, Time: 17843.9373 s, training loss: 0.0373
# Iteration: 25350, Time: 17877.4802 s, training loss: 0.0275
# Iteration: 25400, Time: 17910.9547 s, training loss: 0.0348
# Iteration: 25450, Time: 17944.5453 s, training loss: 0.0419
# Iteration: 25500, Time: 17978.3643 s, training loss: 0.0486
# Iteration: 25550, Time: 18011.8165 s, training loss: 0.0278
# Iteration: 25600, Time: 18045.2582 s, training loss: 0.0405
# Iteration: 25650, Time: 18078.8719 s, training loss: 0.0398
# Iteration: 25700, Time: 18112.5083 s, training loss: 0.0185
# Iteration: 25750, Time: 18146.6364 s, training loss: 0.0293
# Iteration: 25800, Time: 18180.3449 s, training loss: 0.0456
# Iteration: 25850, Time: 18213.9640 s, training loss: 0.0502
# Iteration: 25900, Time: 18247.2317 s, training loss: 0.0404
# Iteration: 25950, Time: 18280.7206 s, training loss: 0.0407
# Iteration: 26000, Time: 18314.4927 s, training loss: 0.0238
# Iteration: 26050, Time: 18348.3185 s, training loss: 0.0199
# Iteration: 26100, Time: 18381.9230 s, training loss: 0.0665
# Iteration: 26150, Time: 18415.1041 s, training loss: 0.0344
# Iteration: 26200, Time: 18448.0564 s, training loss: 0.0331
# Iteration: 26250, Time: 18481.7171 s, training loss: 0.0278
# Iteration: 26300, Time: 18515.3913 s, training loss: 0.0354
# Iteration: 26350, Time: 18549.2102 s, training loss: 0.0401
# Iteration: 26400, Time: 18582.7995 s, training loss: 0.0205
# -----EPOCH16----- done.  Validation loss:  0.09224793068974967
# -----EPOCH17-----
# Iteration: 26450, Time: 18655.8838 s, training loss: 0.0281
# Iteration: 26500, Time: 18689.1423 s, training loss: 0.0338
# Iteration: 26550, Time: 18722.3912 s, training loss: 0.0350
# Iteration: 26600, Time: 18755.6144 s, training loss: 0.0298
# Iteration: 26650, Time: 18789.0909 s, training loss: 0.0253
# Iteration: 26700, Time: 18822.7221 s, training loss: 0.0302
# Iteration: 26750, Time: 18856.5333 s, training loss: 0.0487
# Iteration: 26800, Time: 18889.9496 s, training loss: 0.0463
# Iteration: 26850, Time: 18923.3410 s, training loss: 0.0264
# Iteration: 26900, Time: 18956.8371 s, training loss: 0.0222
# Iteration: 26950, Time: 18990.7811 s, training loss: 0.0189
# Iteration: 27000, Time: 19024.6350 s, training loss: 0.0300
# Iteration: 27050, Time: 19058.5409 s, training loss: 0.0434
# Iteration: 27100, Time: 19092.2533 s, training loss: 0.0283
# Iteration: 27150, Time: 19125.7093 s, training loss: 0.0252
# Iteration: 27200, Time: 19159.0519 s, training loss: 0.0367
# Iteration: 27250, Time: 19193.0412 s, training loss: 0.0300
# Iteration: 27300, Time: 19227.1695 s, training loss: 0.0358
# Iteration: 27350, Time: 19260.8963 s, training loss: 0.0258
# Iteration: 27400, Time: 19294.1323 s, training loss: 0.0321
# Iteration: 27450, Time: 19327.2273 s, training loss: 0.0310
# Iteration: 27500, Time: 19360.9636 s, training loss: 0.0340
# Iteration: 27550, Time: 19394.6787 s, training loss: 0.0570
# Iteration: 27600, Time: 19428.3425 s, training loss: 0.0206
# Iteration: 27650, Time: 19461.8933 s, training loss: 0.0277
# Iteration: 27700, Time: 19495.0270 s, training loss: 0.0372
# Iteration: 27750, Time: 19528.1946 s, training loss: 0.0364
# Iteration: 27800, Time: 19561.7563 s, training loss: 0.0203
# Iteration: 27850, Time: 19595.6085 s, training loss: 0.0485
# Iteration: 27900, Time: 19629.3469 s, training loss: 0.0264
# Iteration: 27950, Time: 19662.8169 s, training loss: 0.0313
# Iteration: 28000, Time: 19696.5797 s, training loss: 0.0493
# Iteration: 28050, Time: 19730.2028 s, training loss: 0.0287
# -----EPOCH17----- done.  Validation loss:  0.07320375643657104
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH18-----
# Iteration: 28100, Time: 19810.6455 s, training loss: 0.0165
# Iteration: 28150, Time: 19843.9152 s, training loss: 0.0484
# Iteration: 28200, Time: 19877.6070 s, training loss: 0.0517
# Iteration: 28250, Time: 19911.6631 s, training loss: 0.0274
# Iteration: 28300, Time: 19945.5089 s, training loss: 0.0252
# Iteration: 28350, Time: 19978.9471 s, training loss: 0.0330
# Iteration: 28400, Time: 20012.1780 s, training loss: 0.0215
# Iteration: 28450, Time: 20045.5375 s, training loss: 0.0288
# Iteration: 28500, Time: 20079.1439 s, training loss: 0.0268
# Iteration: 28550, Time: 20112.9542 s, training loss: 0.0360
# Iteration: 28600, Time: 20146.8378 s, training loss: 0.0243
# Iteration: 28650, Time: 20180.5212 s, training loss: 0.0091
# Iteration: 28700, Time: 20213.9891 s, training loss: 0.0336
# Iteration: 28750, Time: 20247.5570 s, training loss: 0.0286
# Iteration: 28800, Time: 20281.4856 s, training loss: 0.0319
# Iteration: 28850, Time: 20315.2798 s, training loss: 0.0493
# Iteration: 28900, Time: 20349.1896 s, training loss: 0.0482
# Iteration: 28950, Time: 20382.7439 s, training loss: 0.0408
# Iteration: 29000, Time: 20416.2265 s, training loss: 0.0379
# Iteration: 29050, Time: 20449.5376 s, training loss: 0.0320
# Iteration: 29100, Time: 20483.0845 s, training loss: 0.0399
# Iteration: 29150, Time: 20517.4529 s, training loss: 0.0380
# Iteration: 29200, Time: 20551.5671 s, training loss: 0.0362
# Iteration: 29250, Time: 20585.6310 s, training loss: 0.0395
# Iteration: 29300, Time: 20619.2327 s, training loss: 0.0337
# Iteration: 29350, Time: 20652.9495 s, training loss: 0.0200
# Iteration: 29400, Time: 20686.5232 s, training loss: 0.0239
# Iteration: 29450, Time: 20720.4054 s, training loss: 0.0261
# Iteration: 29500, Time: 20754.4765 s, training loss: 0.0298
# Iteration: 29550, Time: 20788.6668 s, training loss: 0.0307
# Iteration: 29600, Time: 20822.1835 s, training loss: 0.0181
# Iteration: 29650, Time: 20855.6208 s, training loss: 0.0123
# Iteration: 29700, Time: 20889.6511 s, training loss: 0.0495
# -----EPOCH18----- done.  Validation loss:  0.08787765736078577
# -----EPOCH19-----
# Iteration: 29750, Time: 20962.8442 s, training loss: 0.0399
# Iteration: 29800, Time: 20996.8738 s, training loss: 0.0223
# Iteration: 29850, Time: 21030.7889 s, training loss: 0.0249
# Iteration: 29900, Time: 21064.8373 s, training loss: 0.0249
# Iteration: 29950, Time: 21098.1571 s, training loss: 0.0222
# Iteration: 30000, Time: 21131.6782 s, training loss: 0.0491
# Iteration: 30050, Time: 21165.0524 s, training loss: 0.0282
# Iteration: 30100, Time: 21198.9220 s, training loss: 0.0344
# Iteration: 30150, Time: 21232.2176 s, training loss: 0.0314
# Iteration: 30200, Time: 21266.0191 s, training loss: 0.0522
# Iteration: 30250, Time: 21299.2291 s, training loss: 0.0340
# Iteration: 30300, Time: 21332.3363 s, training loss: 0.0363
# Iteration: 30350, Time: 21365.9483 s, training loss: 0.0255
# Iteration: 30400, Time: 21399.5972 s, training loss: 0.0366
# Iteration: 30450, Time: 21433.4667 s, training loss: 0.0398
# Iteration: 30500, Time: 21466.7880 s, training loss: 0.0249
# Iteration: 30550, Time: 21500.3146 s, training loss: 0.0343
# Iteration: 30600, Time: 21533.4330 s, training loss: 0.0510
# Iteration: 30650, Time: 21567.1104 s, training loss: 0.0404
# Iteration: 30700, Time: 21600.8978 s, training loss: 0.0174
# Iteration: 30750, Time: 21634.5032 s, training loss: 0.0298
# Iteration: 30800, Time: 21668.1077 s, training loss: 0.0350
# Iteration: 30850, Time: 21701.1952 s, training loss: 0.0282
# Iteration: 30900, Time: 21734.4824 s, training loss: 0.0344
# Iteration: 30950, Time: 21768.3532 s, training loss: 0.0314
# Iteration: 31000, Time: 21802.3739 s, training loss: 0.0175
# Iteration: 31050, Time: 21836.4645 s, training loss: 0.0338
# Iteration: 31100, Time: 21869.8325 s, training loss: 0.0232
# Iteration: 31150, Time: 21903.1492 s, training loss: 0.0241
# Iteration: 31200, Time: 21936.6849 s, training loss: 0.0373
# Iteration: 31250, Time: 21970.4043 s, training loss: 0.0343
# Iteration: 31300, Time: 22004.0757 s, training loss: 0.0392
# Iteration: 31350, Time: 22037.8425 s, training loss: 0.0245
# -----EPOCH19----- done.  Validation loss:  0.08494835435390688
# -----EPOCH20-----
# Iteration: 31400, Time: 22110.9873 s, training loss: 0.0564
# Iteration: 31450, Time: 22144.6411 s, training loss: 0.0319
# Iteration: 31500, Time: 22178.0230 s, training loss: 0.0307
# Iteration: 31550, Time: 22211.4706 s, training loss: 0.0306
# Iteration: 31600, Time: 22244.9253 s, training loss: 0.0303
# Iteration: 31650, Time: 22278.7123 s, training loss: 0.0227
# Iteration: 31700, Time: 22312.9576 s, training loss: 0.0569
# Iteration: 31750, Time: 22346.7148 s, training loss: 0.0254
# Iteration: 31800, Time: 22380.3266 s, training loss: 0.0407
# Iteration: 31850, Time: 22413.5999 s, training loss: 0.0448
# Iteration: 31900, Time: 22447.1299 s, training loss: 0.0219
# Iteration: 31950, Time: 22480.8572 s, training loss: 0.0586
# Iteration: 32000, Time: 22514.3717 s, training loss: 0.0320
# Iteration: 32050, Time: 22547.9947 s, training loss: 0.0401
# Iteration: 32100, Time: 22581.4308 s, training loss: 0.0419
# Iteration: 32150, Time: 22614.8893 s, training loss: 0.0436
# Iteration: 32200, Time: 22648.6201 s, training loss: 0.0346
# Iteration: 32250, Time: 22682.3043 s, training loss: 0.0154
# Iteration: 32300, Time: 22716.1854 s, training loss: 0.0262
# Iteration: 32350, Time: 22749.6861 s, training loss: 0.0513
# Iteration: 32400, Time: 22783.0133 s, training loss: 0.0398
# Iteration: 32450, Time: 22816.3090 s, training loss: 0.0322
# Iteration: 32500, Time: 22849.9747 s, training loss: 0.0215
# Iteration: 32550, Time: 22883.8903 s, training loss: 0.0403
# Iteration: 32600, Time: 22917.7156 s, training loss: 0.0455
# Iteration: 32650, Time: 22951.1904 s, training loss: 0.0448
# Iteration: 32700, Time: 22984.2007 s, training loss: 0.0355
# Iteration: 32750, Time: 23017.8002 s, training loss: 0.0360
# Iteration: 32800, Time: 23051.9309 s, training loss: 0.0497
# Iteration: 32850, Time: 23086.0911 s, training loss: 0.0299
# Iteration: 32900, Time: 23120.3783 s, training loss: 0.0385
# Iteration: 32950, Time: 23154.4796 s, training loss: 0.0262
# Iteration: 33000, Time: 23188.4430 s, training loss: 0.0273
# -----EPOCH20----- done.  Validation loss:  0.07270329236567542
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH21-----
# Iteration: 33050, Time: 23271.3603 s, training loss: 0.0299
# Iteration: 33100, Time: 23304.8467 s, training loss: 0.0420
# Iteration: 33150, Time: 23338.5081 s, training loss: 0.0369
# Iteration: 33200, Time: 23372.6689 s, training loss: 0.0347
# Iteration: 33250, Time: 23406.7753 s, training loss: 0.0288
# Iteration: 33300, Time: 23440.9392 s, training loss: 0.0211
# Iteration: 33350, Time: 23474.8984 s, training loss: 0.0466
# Iteration: 33400, Time: 23508.3664 s, training loss: 0.0327
# Iteration: 33450, Time: 23542.2663 s, training loss: 0.0344
# Iteration: 33500, Time: 23576.1711 s, training loss: 0.0482
# Iteration: 33550, Time: 23610.3625 s, training loss: 0.0265
# Iteration: 33600, Time: 23644.5631 s, training loss: 0.0344
# Iteration: 33650, Time: 23678.7898 s, training loss: 0.0392
# Iteration: 33700, Time: 23712.5635 s, training loss: 0.0190
# Iteration: 33750, Time: 23746.8627 s, training loss: 0.0446
# Iteration: 33800, Time: 23781.1889 s, training loss: 0.0408
# Iteration: 33850, Time: 23815.6882 s, training loss: 0.0368
# Iteration: 33900, Time: 23850.2039 s, training loss: 0.0444
# Iteration: 33950, Time: 23884.7677 s, training loss: 0.0289
# Iteration: 34000, Time: 23919.3235 s, training loss: 0.0323
# Iteration: 34050, Time: 23953.6828 s, training loss: 0.0361
# Iteration: 34100, Time: 23988.2338 s, training loss: 0.0208
# Iteration: 34150, Time: 24023.2108 s, training loss: 0.0387
# Iteration: 34200, Time: 24057.8525 s, training loss: 0.0435
# Iteration: 34250, Time: 24092.3441 s, training loss: 0.0405
# Iteration: 34300, Time: 24126.6516 s, training loss: 0.0178
# Iteration: 34350, Time: 24161.2015 s, training loss: 0.0422
# Iteration: 34400, Time: 24196.3211 s, training loss: 0.0272
# Iteration: 34450, Time: 24231.9413 s, training loss: 0.0238
# Iteration: 34500, Time: 24267.7413 s, training loss: 0.0423
# Iteration: 34550, Time: 24302.9221 s, training loss: 0.0438
# Iteration: 34600, Time: 24338.3475 s, training loss: 0.0601
# Iteration: 34650, Time: 24373.6005 s, training loss: 0.0338
# -----EPOCH21----- done.  Validation loss:  0.08077658377782349
# -----EPOCH22-----
# Iteration: 34700, Time: 24454.6153 s, training loss: 0.0369
# Iteration: 34750, Time: 24489.0424 s, training loss: 0.0493
# Iteration: 34800, Time: 24522.9318 s, training loss: 0.0223
# Iteration: 34850, Time: 24557.0440 s, training loss: 0.0534
# Iteration: 34900, Time: 24591.2917 s, training loss: 0.0488
# Iteration: 34950, Time: 24625.0639 s, training loss: 0.0423
# Iteration: 35000, Time: 24658.7702 s, training loss: 0.0407
# Iteration: 35050, Time: 24693.0897 s, training loss: 0.0371
# Iteration: 35100, Time: 24727.6769 s, training loss: 0.0212
# Iteration: 35150, Time: 24762.0667 s, training loss: 0.0266
# Iteration: 35200, Time: 24796.3868 s, training loss: 0.0250
# Iteration: 35250, Time: 24830.4896 s, training loss: 0.0443
# Iteration: 35300, Time: 24865.0231 s, training loss: 0.0378
# Iteration: 35350, Time: 24899.6263 s, training loss: 0.0515
# Iteration: 35400, Time: 24934.2312 s, training loss: 0.0358
# Iteration: 35450, Time: 24969.0692 s, training loss: 0.0281
# Iteration: 35500, Time: 25003.5620 s, training loss: 0.0304
# Iteration: 35550, Time: 25037.6799 s, training loss: 0.0459
# Iteration: 35600, Time: 25072.2392 s, training loss: 0.0467
# Iteration: 35650, Time: 25107.1248 s, training loss: 0.0213
# Iteration: 35700, Time: 25142.4299 s, training loss: 0.0345
# Iteration: 35750, Time: 25177.5142 s, training loss: 0.0443
# Iteration: 35800, Time: 25211.9258 s, training loss: 0.0331
# Iteration: 35850, Time: 25246.2369 s, training loss: 0.0181
# Iteration: 35900, Time: 25281.0173 s, training loss: 0.0325
# Iteration: 35950, Time: 25315.8223 s, training loss: 0.0199
# Iteration: 36000, Time: 25350.5643 s, training loss: 0.0173
# Iteration: 36050, Time: 25385.5552 s, training loss: 0.0326
# Iteration: 36100, Time: 25420.1253 s, training loss: 0.0223
# Iteration: 36150, Time: 25454.9596 s, training loss: 0.0575
# Iteration: 36200, Time: 25489.8426 s, training loss: 0.0202
# Iteration: 36250, Time: 25524.7609 s, training loss: 0.0379
# Iteration: 36300, Time: 25559.6940 s, training loss: 0.0239
# -----EPOCH22----- done.  Validation loss:  0.08252938715189445
# -----EPOCH23-----
# Iteration: 36350, Time: 25638.2716 s, training loss: 0.0313
# Iteration: 36400, Time: 25672.2517 s, training loss: 0.0179
# Iteration: 36450, Time: 25706.6067 s, training loss: 0.0338
# Iteration: 36500, Time: 25740.3290 s, training loss: 0.0477
# Iteration: 36550, Time: 25774.0571 s, training loss: 0.0355
# Iteration: 36600, Time: 25808.3137 s, training loss: 0.0479
# Iteration: 36650, Time: 25842.7343 s, training loss: 0.0400
# Iteration: 36700, Time: 25877.0564 s, training loss: 0.0384
# Iteration: 36750, Time: 25910.8483 s, training loss: 0.0253
# Iteration: 36800, Time: 25944.5599 s, training loss: 0.0302
# Iteration: 36850, Time: 25978.4786 s, training loss: 0.0437
# Iteration: 36900, Time: 26012.7576 s, training loss: 0.0247
# Iteration: 36950, Time: 26047.0510 s, training loss: 0.0421
# Iteration: 37000, Time: 26081.6053 s, training loss: 0.0334
# Iteration: 37050, Time: 26116.0097 s, training loss: 0.0546
# Iteration: 37100, Time: 26149.8723 s, training loss: 0.0225
# Iteration: 37150, Time: 26184.0281 s, training loss: 0.0179
# Iteration: 37200, Time: 26218.2339 s, training loss: 0.0323
# Iteration: 37250, Time: 26252.9501 s, training loss: 0.0394
# Iteration: 37300, Time: 26287.6011 s, training loss: 0.0633
# Iteration: 37350, Time: 26321.8179 s, training loss: 0.0214
# Iteration: 37400, Time: 26355.9227 s, training loss: 0.0350
# Iteration: 37450, Time: 26389.9634 s, training loss: 0.0381
# Iteration: 37500, Time: 26424.4577 s, training loss: 0.0412
# Iteration: 37550, Time: 26458.9629 s, training loss: 0.0438
# Iteration: 37600, Time: 26493.3011 s, training loss: 0.0372
# Iteration: 37650, Time: 26527.3882 s, training loss: 0.0377
# Iteration: 37700, Time: 26561.4967 s, training loss: 0.0541
# ...
# Iteration: 45450, Time: 32007.4804 s, training loss: 0.0465
# Iteration: 45500, Time: 32040.8225 s, training loss: 0.0307
# Iteration: 45550, Time: 32074.4533 s, training loss: 0.0277
# Iteration: 45600, Time: 32108.4443 s, training loss: 0.0241
# Iteration: 45650, Time: 32142.2116 s, training loss: 0.0123
# Iteration: 45700, Time: 32176.1780 s, training loss: 0.0306
# Iteration: 45750, Time: 32209.3807 s, training loss: 0.0358
# Iteration: 45800, Time: 32242.9224 s, training loss: 0.0486
# Iteration: 45850, Time: 32276.9577 s, training loss: 0.0248
# Iteration: 45900, Time: 32311.4032 s, training loss: 0.0485
# Iteration: 45950, Time: 32345.8547 s, training loss: 0.0325
# Iteration: 46000, Time: 32379.8417 s, training loss: 0.0363
# Iteration: 46050, Time: 32413.6820 s, training loss: 0.0301
# Iteration: 46100, Time: 32447.3889 s, training loss: 0.0265
# Iteration: 46150, Time: 32481.6759 s, training loss: 0.0336
# Iteration: 46200, Time: 32515.7053 s, training loss: 0.0325
# -----EPOCH28----- done.  Validation loss:  0.07308592105565713
# -----EPOCH29-----
# Iteration: 46250, Time: 32588.8902 s, training loss: 0.0493
# Iteration: 46300, Time: 32622.8200 s, training loss: 0.0260
# Iteration: 46350, Time: 32656.8704 s, training loss: 0.0362
# Iteration: 46400, Time: 32690.3400 s, training loss: 0.0370
# Iteration: 46450, Time: 32723.4488 s, training loss: 0.0307
# Iteration: 46500, Time: 32756.9739 s, training loss: 0.0385
# Iteration: 46550, Time: 32790.6994 s, training loss: 0.0433
# Iteration: 46600, Time: 32824.3273 s, training loss: 0.0325
# Iteration: 46650, Time: 32858.1942 s, training loss: 0.0313
# Iteration: 46700, Time: 32891.6160 s, training loss: 0.0294
# Iteration: 46750, Time: 32924.7360 s, training loss: 0.0347
# Iteration: 46800, Time: 32958.0966 s, training loss: 0.0359
# Iteration: 46850, Time: 32991.8435 s, training loss: 0.0337
# Iteration: 46900, Time: 33025.6230 s, training loss: 0.0377
# Iteration: 46950, Time: 33059.3286 s, training loss: 0.0279
# Iteration: 47000, Time: 33092.4894 s, training loss: 0.0276
# Iteration: 47050, Time: 33125.6792 s, training loss: 0.0308
# Iteration: 47100, Time: 33159.1031 s, training loss: 0.0198
# Iteration: 47150, Time: 33192.9679 s, training loss: 0.0392
# Iteration: 47200, Time: 33226.8847 s, training loss: 0.0152
# Iteration: 47250, Time: 33260.6575 s, training loss: 0.0376
# Iteration: 47300, Time: 33294.2891 s, training loss: 0.0292
# Iteration: 47350, Time: 33327.9166 s, training loss: 0.0218
# Iteration: 47400, Time: 33361.5313 s, training loss: 0.0202
# Iteration: 47450, Time: 33395.3587 s, training loss: 0.0301
# Iteration: 47500, Time: 33429.2171 s, training loss: 0.0196
# Iteration: 47550, Time: 33463.4093 s, training loss: 0.0261
# Iteration: 47600, Time: 33497.3277 s, training loss: 0.0378
# Iteration: 47650, Time: 33531.0753 s, training loss: 0.0565
# Iteration: 47700, Time: 33564.9609 s, training loss: 0.0336
# Iteration: 47750, Time: 33599.3430 s, training loss: 0.0559
# Iteration: 47800, Time: 33633.8640 s, training loss: 0.0416
# Iteration: 47850, Time: 33668.4167 s, training loss: 0.0257
# -----EPOCH29----- done.  Validation loss:  0.07765367985927217
# -----EPOCH30-----
# Iteration: 47900, Time: 33741.9250 s, training loss: 0.0235
# Iteration: 47950, Time: 33775.5977 s, training loss: 0.0441
# Iteration: 48000, Time: 33808.6749 s, training loss: 0.0286
# Iteration: 48050, Time: 33842.2825 s, training loss: 0.0229
# Iteration: 48100, Time: 33875.7578 s, training loss: 0.0279
# Iteration: 48150, Time: 33909.5634 s, training loss: 0.0223
# Iteration: 48200, Time: 33943.5514 s, training loss: 0.0201
# Iteration: 48250, Time: 33977.2959 s, training loss: 0.0662
# Iteration: 48300, Time: 34010.8805 s, training loss: 0.0496
# Iteration: 48350, Time: 34044.0289 s, training loss: 0.0242
# Iteration: 48400, Time: 34077.6323 s, training loss: 0.0407
# Iteration: 48450, Time: 34111.3639 s, training loss: 0.0367
# Iteration: 48500, Time: 34145.3222 s, training loss: 0.0372
# Iteration: 48550, Time: 34178.7495 s, training loss: 0.0444
# Iteration: 48600, Time: 34212.1590 s, training loss: 0.0410
# Iteration: 48650, Time: 34245.4629 s, training loss: 0.0229
# Iteration: 48700, Time: 34279.3069 s, training loss: 0.0209
# Iteration: 48750, Time: 34313.4442 s, training loss: 0.0304
# Iteration: 48800, Time: 34347.5784 s, training loss: 0.0267
# Iteration: 48850, Time: 34381.1087 s, training loss: 0.0296
# Iteration: 48900, Time: 34414.8327 s, training loss: 0.0236
# Iteration: 48950, Time: 34448.9152 s, training loss: 0.0417
# Iteration: 49000, Time: 34483.0554 s, training loss: 0.0221
# Iteration: 49050, Time: 34517.3257 s, training loss: 0.0406
# Iteration: 49100, Time: 34551.2733 s, training loss: 0.0402
# Iteration: 49150, Time: 34585.2835 s, training loss: 0.0429
# Iteration: 49200, Time: 34619.1233 s, training loss: 0.0217
# Iteration: 49250, Time: 34652.8975 s, training loss: 0.0196
# Iteration: 49300, Time: 34687.1017 s, training loss: 0.0418
# Iteration: 49350, Time: 34721.2991 s, training loss: 0.0316
# Iteration: 49400, Time: 34755.7113 s, training loss: 0.0273
# Iteration: 49450, Time: 34789.6628 s, training loss: 0.0329
# Iteration: 49500, Time: 34823.4818 s, training loss: 0.0404
# -----EPOCH30----- done.  Validation loss:  0.07242309661082874
# validation loss improoved saving checkpoint...
# checkpoint saved to: ./model.pt
# -----EPOCH31-----
# Iteration: 49550, Time: 34904.1914 s, training loss: 0.0377
# Iteration: 49600, Time: 34937.3471 s, training loss: 0.0449
# Iteration: 49650, Time: 34971.2385 s, training loss: 0.0250
# Iteration: 49700, Time: 35005.3591 s, training loss: 0.0267
# Iteration: 49750, Time: 35039.1307 s, training loss: 0.0431
# Iteration: 49800, Time: 35072.6818 s, training loss: 0.0326
# Iteration: 49850, Time: 35106.2759 s, training loss: 0.0393
# Iteration: 49900, Time: 35139.7744 s, training loss: 0.0228
# Iteration: 49950, Time: 35173.4830 s, training loss: 0.0421
# Iteration: 50000, Time: 35207.1497 s, training loss: 0.0259
# Iteration: 50050, Time: 35240.9816 s, training loss: 0.0418
# Iteration: 50100, Time: 35274.6065 s, training loss: 0.0325
# Iteration: 50150, Time: 35308.3155 s, training loss: 0.0270
# Iteration: 50200, Time: 35341.5203 s, training loss: 0.0494
# Iteration: 50250, Time: 35375.3841 s, training loss: 0.0210
# Iteration: 50300, Time: 35409.7134 s, training loss: 0.0421
# Iteration: 50350, Time: 35443.3510 s, training loss: 0.0308
# Iteration: 50400, Time: 35476.7500 s, training loss: 0.0485
# Iteration: 50450, Time: 35510.1702 s, training loss: 0.0299
# Iteration: 50500, Time: 35543.8009 s, training loss: 0.0325
# Iteration: 50550, Time: 35577.8419 s, training loss: 0.0213
# Iteration: 50600, Time: 35611.9057 s, training loss: 0.0288
# Iteration: 50650, Time: 35645.5675 s, training loss: 0.0344
# Iteration: 50700, Time: 35678.6912 s, training loss: 0.0419
# Iteration: 50750, Time: 35712.0615 s, training loss: 0.0623
# Iteration: 50800, Time: 35745.6386 s, training loss: 0.0468
# Iteration: 50850, Time: 35779.7062 s, training loss: 0.0341
# Iteration: 50900, Time: 35813.5066 s, training loss: 0.0377
# Iteration: 50950, Time: 35847.2778 s, training loss: 0.0598
# Iteration: 51000, Time: 35880.7250 s, training loss: 0.0443
# Iteration: 51050, Time: 35914.2159 s, training loss: 0.0376
# Iteration: 51100, Time: 35947.8559 s, training loss: 0.0355
# Iteration: 51150, Time: 35981.9096 s, training loss: 0.0450
# -----EPOCH31----- done.  Validation loss:  0.08732560865607064
# -----EPOCH32-----
# Iteration: 51200, Time: 36055.2226 s, training loss: 0.0595
# Iteration: 51250, Time: 36088.7482 s, training loss: 0.0381
# Iteration: 51300, Time: 36122.7387 s, training loss: 0.0347
# Iteration: 51350, Time: 36156.3516 s, training loss: 0.0373
# Iteration: 51400, Time: 36189.5834 s, training loss: 0.0201
# Iteration: 51450, Time: 36222.8273 s, training loss: 0.0407
# Iteration: 51500, Time: 36256.1099 s, training loss: 0.0392
# Iteration: 51550, Time: 36289.8441 s, training loss: 0.0473
# Iteration: 51600, Time: 36323.5621 s, training loss: 0.0487
# Iteration: 51650, Time: 36357.4216 s, training loss: 0.0345
# Iteration: 51700, Time: 36390.6721 s, training loss: 0.0375
# Iteration: 51750, Time: 36424.1801 s, training loss: 0.0159
# Iteration: 51800, Time: 36457.8127 s, training loss: 0.0285
# Iteration: 51850, Time: 36494.3285 s, training loss: 0.0418
# Iteration: 51900, Time: 36528.2643 s, training loss: 0.0181
# Iteration: 51950, Time: 36561.8174 s, training loss: 0.0386
# Iteration: 52000, Time: 36595.2870 s, training loss: 0.0350
# Iteration: 52050, Time: 36628.9337 s, training loss: 0.0239
# Iteration: 52100, Time: 36662.5623 s, training loss: 0.0366
# Iteration: 52150, Time: 36696.4039 s, training loss: 0.0245
# Iteration: 52200, Time: 36730.3743 s, training loss: 0.0335
# Iteration: 52250, Time: 36764.4323 s, training loss: 0.0470
# Iteration: 52300, Time: 36797.5462 s, training loss: 0.0246
# Iteration: 52350, Time: 36830.6547 s, training loss: 0.0362
# Iteration: 52400, Time: 36864.2771 s, training loss: 0.0272
# Iteration: 52450, Time: 36897.9441 s, training loss: 0.0185
# Iteration: 52500, Time: 36931.9151 s, training loss: 0.0382
# Iteration: 52550, Time: 36965.5675 s, training loss: 0.0181
# Iteration: 52600, Time: 36998.8305 s, training loss: 0.0307
# Iteration: 52650, Time: 37032.2491 s, training loss: 0.0279
# Iteration: 52700, Time: 37065.6731 s, training loss: 0.0242
# Iteration: 52750, Time: 37099.5421 s, training loss: 0.0277
# Iteration: 52800, Time: 37133.2045 s, training loss: 0.0252
# -----EPOCH32----- done.  Validation loss:  0.08572060570861101
# -----EPOCH33-----
# Iteration: 52850, Time: 37206.9341 s, training loss: 0.0291
# Iteration: 52900, Time: 37241.1790 s, training loss: 0.0421
# Iteration: 52950, Time: 37274.7904 s, training loss: 0.0458
# Iteration: 53000, Time: 37307.8946 s, training loss: 0.0280
# Iteration: 53050, Time: 37341.4286 s, training loss: 0.0345
# Iteration: 53100, Time: 37375.2704 s, training loss: 0.0296
# Iteration: 53150, Time: 37408.9259 s, training loss: 0.0402
# Iteration: 53200, Time: 37442.7351 s, training loss: 0.0236
# Iteration: 53250, Time: 37476.0680 s, training loss: 0.0408
# Iteration: 53300, Time: 37509.4393 s, training loss: 0.0396
# Iteration: 53350, Time: 37542.9023 s, training loss: 0.0429
# Iteration: 53400, Time: 37576.4447 s, training loss: 0.0275
# Iteration: 53450, Time: 37610.0782 s, training loss: 0.0242
# Iteration: 53500, Time: 37643.8841 s, training loss: 0.0323
# Iteration: 53550, Time: 37676.8032 s, training loss: 0.0284
# Iteration: 53600, Time: 37710.1685 s, training loss: 0.0367
# Iteration: 53650, Time: 37743.9474 s, training loss: 0.0314
# Iteration: 53700, Time: 37778.0020 s, training loss: 0.0221
# Iteration: 53750, Time: 37811.8296 s, training loss: 0.0244
# Iteration: 53800, Time: 37845.5063 s, training loss: 0.0292
# Iteration: 53850, Time: 37878.9855 s, training loss: 0.0220
# Iteration: 53900, Time: 37912.3703 s, training loss: 0.0400
# Iteration: 53950, Time: 37946.2255 s, training loss: 0.0353
# Iteration: 54000, Time: 37980.1340 s, training loss: 0.0233
# Iteration: 54050, Time: 38014.0220 s, training loss: 0.0396
# Iteration: 54100, Time: 38047.5572 s, training loss: 0.0349
# Iteration: 54150, Time: 38080.8976 s, training loss: 0.0448
# Iteration: 54200, Time: 38114.1979 s, training loss: 0.0216
# Iteration: 54250, Time: 38147.8716 s, training loss: 0.0390
# Iteration: 54300, Time: 38182.0089 s, training loss: 0.0263
# Iteration: 54350, Time: 38216.0510 s, training loss: 0.0508
# Iteration: 54400, Time: 38249.5477 s, training loss: 0.0109
# Iteration: 54450, Time: 38282.8125 s, training loss: 0.0643
# -----EPOCH33----- done.  Validation loss:  0.08176958022432504
# -----EPOCH34-----
# Iteration: 54500, Time: 38355.5366 s, training loss: 0.0284
# Iteration: 54550, Time: 38388.9525 s, training loss: 0.0265
# Iteration: 54600, Time: 38422.3811 s, training loss: 0.0314
# Iteration: 54650, Time: 38456.2846 s, training loss: 0.0400
# Iteration: 54700, Time: 38489.9468 s, training loss: 0.0279
# Iteration: 54750, Time: 38523.9864 s, training loss: 0.0437
# Iteration: 54800, Time: 38557.3023 s, training loss: 0.0196
# Iteration: 54850, Time: 38590.6268 s, training loss: 0.0268
# Iteration: 54900, Time: 38624.4768 s, training loss: 0.0255
# Iteration: 54950, Time: 38658.5785 s, training loss: 0.0357
# Iteration: 55000, Time: 38692.6043 s, training loss: 0.0188
# Iteration: 55050, Time: 38726.6173 s, training loss: 0.0434
# Iteration: 55100, Time: 38760.0843 s, training loss: 0.0462
# Iteration: 55150, Time: 38793.5042 s, training loss: 0.0379
# Iteration: 55200, Time: 38827.0424 s, training loss: 0.0195
# Iteration: 55250, Time: 38860.6270 s, training loss: 0.0075
# Iteration: 55300, Time: 38894.5056 s, training loss: 0.0387
# Iteration: 55350, Time: 38928.2528 s, training loss: 0.0212
# Iteration: 55400, Time: 38961.7353 s, training loss: 0.0545
# Iteration: 55450, Time: 38995.6426 s, training loss: 0.0257
# Iteration: 55500, Time: 39029.8178 s, training loss: 0.0340
# Iteration: 55550, Time: 39063.6335 s, training loss: 0.0389
# Iteration: 55600, Time: 39097.6550 s, training loss: 0.0495
# Iteration: 55650, Time: 39131.6879 s, training loss: 0.0364
# Iteration: 55700, Time: 39165.2777 s, training loss: 0.0465
# Iteration: 55750, Time: 39198.9080 s, training loss: 0.0554
# Iteration: 55800, Time: 39232.7119 s, training loss: 0.0433
# Iteration: 55850, Time: 39266.5702 s, training loss: 0.0245
# Iteration: 55900, Time: 39300.6391 s, training loss: 0.0381
# Iteration: 55950, Time: 39334.4478 s, training loss: 0.0437
# Iteration: 56000, Time: 39367.9287 s, training loss: 0.0248
# Iteration: 56050, Time: 39401.3299 s, training loss: 0.0514
# Iteration: 56100, Time: 39435.2599 s, training loss: 0.0340
# -----EPOCH34----- done.  Validation loss:  0.07484206231382691
# -----EPOCH35-----
# Iteration: 56150, Time: 39509.3632 s, training loss: 0.0366
# Iteration: 56200, Time: 39543.0545 s, training loss: 0.0244
# Iteration: 56250, Time: 39577.0227 s, training loss: 0.0597
# Iteration: 56300, Time: 39610.8691 s, training loss: 0.0207
# Iteration: 56350, Time: 39644.5703 s, training loss: 0.0279
# Iteration: 56400, Time: 39678.1029 s, training loss: 0.0325
# Iteration: 56450, Time: 39711.5918 s, training loss: 0.0420
# Iteration: 56500, Time: 39745.1456 s, training loss: 0.0341
# Iteration: 56550, Time: 39779.1574 s, training loss: 0.0456
# Iteration: 56600, Time: 39812.8797 s, training loss: 0.0246
# Iteration: 56650, Time: 39846.4376 s, training loss: 0.0208
# Iteration: 56700, Time: 39879.9545 s, training loss: 0.0407
# Iteration: 56750, Time: 39913.5540 s, training loss: 0.0284
# Iteration: 56800, Time: 39947.3527 s, training loss: 0.0363
# Iteration: 56850, Time: 39981.5094 s, training loss: 0.0184
# Iteration: 56900, Time: 40015.2078 s, training loss: 0.0236
# Iteration: 56950, Time: 40048.9741 s, training loss: 0.0297
# Iteration: 57000, Time: 40082.2662 s, training loss: 0.0264
# Iteration: 57050, Time: 40115.8816 s, training loss: 0.0413
# Iteration: 57100, Time: 40149.7246 s, training loss: 0.0337
# Iteration: 57150, Time: 40183.7318 s, training loss: 0.0368
# Iteration: 57200, Time: 40218.0274 s, training loss: 0.0527
# Iteration: 57250, Time: 40251.3096 s, training loss: 0.0636
# Iteration: 57300, Time: 40284.8025 s, training loss: 0.0316
# Iteration: 57350, Time: 40318.5102 s, training loss: 0.0345
# Iteration: 57400, Time: 40352.3055 s, training loss: 0.0229
# Iteration: 57450, Time: 40386.1192 s, training loss: 0.0245
# Iteration: 57500, Time: 40419.8034 s, training loss: 0.0359
# Iteration: 57550, Time: 40453.0350 s, training loss: 0.0297
# Iteration: 57600, Time: 40486.4085 s, training loss: 0.0541
# Iteration: 57650, Time: 40520.2028 s, training loss: 0.0432
# Iteration: 57700, Time: 40554.2367 s, training loss: 0.0601
# Iteration: 57750, Time: 40588.2433 s, training loss: 0.0397
# -----EPOCH35----- done.  Validation loss:  0.07750615831791313
# loading best model...
# /opt/conda/lib/python3.10/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /opt/conda/lib/python3.10/site-packages/torch_geometric/warnings.py:17: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
